# %% [markdown]
# <a href="https://colab.research.google.com/github/vikxoxo/Miscl/blob/master/Kaggle_DataUpload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount the Drive
#
# *  Download the Kaggle api .json file
# *  Upload that .json file in the directery in the drive where you want to upload the dataset
#
#
#
#
# Run below commnands

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/GC10-DET"

# %%
#changing the working directory
# %cd /content/drive/MyDrive/GC10-DET
#Check the present working directory using pwd command
# Out:
# /content/drive/MyDrive/GC10-DET

# %%
# !ls
# Out:
# kaggle.json

# %% [markdown]
# Copy paste Dataset api command from kaggle

# %%
# !kaggle datasets download -d alex000kim/gc10det
# Out:
# ...
#  99% 920M/926M [00:08<00:00, 136MB/s]
# 100% 926M/926M [00:08<00:00, 120MB/s]

# %%
# !ls
# Out:
# gc10det.zip  kaggle.json

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  gc10det.zip
#   inflating: 1/img_02_425501900_00017.jpg
#   inflating: 1/img_02_425502300_00018.jpg
#   inflating: 1/img_02_425503100_00017.jpg
#   inflating: 1/img_02_425505500_00018.jpg
#   inflating: 1/img_02_425506300_00018.jpg
#   inflating: 1/img_02_425506400_00018.jpg
#   inflating: 1/img_02_425507200_00018.jpg
#   inflating: 1/img_02_425508300_00017.jpg
#   inflating: 1/img_02_425613600_00582.jpg
#   inflating: 1/img_02_425614700_00001.jpg
#   inflating: 1/img_02_425616500_00001.jpg
#   inflating: 1/img_02_425637700_00001.jpg
#   inflating: 1/img_02_425637800_00891.jpg
#   inflating: 1/img_02_425637900_00899.jpg
#   inflating: 1/img_02_425640000_00634.jpg
#   inflating: 1/img_02_425640100_00874.jpg
#   inflating: 1/img_02_425644200_00681.jpg
#   inflating: 1/img_02_425644600_00001.jpg
#   inflating: 1/img_03_3403331900_01545.jpg
#   inflating: 1/img_03_3403392000_01070.jpg
#   inflating: 1/img_03_3403392100_00870.jpg
#   inflating: 1/img_03_3403393700_00942.jpg
# ...
